# %% [markdown]
# <a href="https://colab.research.google.com/github/nisharajupal/16-Neural_Network/blob/main/Assignment_16_Neural_Network_ForestFire_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import keras
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #Import Dataset

# %%
df1=pd.read_csv('/content/forestfires.csv')
df1.head()
# Out:
#   month  day  FFMC   DMC  ...  monthnov  monthoct  monthsep  size_category
# 0   mar  fri  86.2  26.2  ...         0         0         0          small
# 1   oct  tue  90.6  35.4  ...         0         1         0          small
# 2   oct  sat  90.6  43.7  ...         0         1         0          small
# 3   mar  fri  91.7  33.3  ...         0         0         0          small
# 4   mar  sun  89.3  51.3  ...         0         0         0          small
#
# [5 rows x 31 columns]

# %% [markdown]
# #EDA

# %%
df1.dtypes
# Out:
# month             object
# day               object
# FFMC             float64
# DMC              float64
# DC               float64
# ISI              float64
# temp             float64
# RH                 int64
# wind             float64
# rain             float64
# area             float64
# dayfri             int64
# daymon             int64
# daysat             int64
# daysun             int64
# daythu             int64
# daytue             int64
# daywed             int64
# monthapr           int64
# monthaug           int64
# monthdec           int64
# monthfeb           int64
# monthjan           int64
# monthjul           int64
# monthjun           int64
# monthmar           int64
# monthmay           int64
# monthnov           int64
# monthoct           int64
# monthsep           int64
# size_category     object
# dtype: object

# %%
df1.shape
# Out:
# (517, 31)

# %%
df1.isnull().sum()
# Out:
# month            0
# day              0
# FFMC             0
# DMC              0
# DC               0
# ISI              0
# temp             0
# RH               0
# wind             0
# rain             0
# area             0
# dayfri           0
# daymon           0
# daysat           0
# daysun           0
# daythu           0
# daytue           0
# daywed           0
# monthapr         0
# monthaug         0
# monthdec         0
# monthfeb         0
# monthjan         0
# monthjul         0
# monthjun         0
# monthmar         0
# monthmay         0
# monthnov         0
# monthoct         0
# monthsep         0
# size_category    0
# dtype: int64

# %%
df2=df1.drop(['month','day'],axis=1)
df2.head()
# Out:
#    FFMC   DMC     DC  ISI  ...  monthnov  monthoct  monthsep  size_category
# 0  86.2  26.2   94.3  5.1  ...         0         0         0          small
# 1  90.6  35.4  669.1  6.7  ...         0         1         0          small
# 2  90.6  43.7  686.9  6.7  ...         0         1         0          small
# 3  91.7  33.3   77.5  9.0  ...         0         0         0          small
# 4  89.3  51.3  102.2  9.6  ...         0         0         0          small
#
# [5 rows x 29 columns]

# %% [markdown]
# #Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
#Applying Label encoding to size_category column and adding result in new column named y
df2['size_category']=lb.fit_transform(df2['size_category'])
df2
# Out:
#      FFMC    DMC     DC   ISI  ...  monthnov  monthoct  monthsep  size_category
# 0    86.2   26.2   94.3   5.1  ...         0         0         0              1
# 1    90.6   35.4  669.1   6.7  ...         0         1         0              1
# 2    90.6   43.7  686.9   6.7  ...         0         1         0              1
# 3    91.7   33.3   77.5   9.0  ...         0         0         0              1
# 4    89.3   51.3  102.2   9.6  ...         0         0         0              1
# ..    ...    ...    ...   ...  ...       ...       ...       ...            ...
# 512  81.6   56.7  665.6   1.9  ...         0         0         0              0
# 513  81.6   56.7  665.6   1.9  ...         0         0         0              0
# 514  81.6   56.7  665.6   1.9  ...         0         0         0              0
# 515  94.4  146.0  614.7  11.3  ...         0         0         0              1
# 516  79.5    3.0  106.7   1.1  ...         1         0         0              1
#
# ...

# %%
df=df2.values
df.shape
# Out:
# (517, 29)

# %%
x=df[:,0:28]
y=df[:,-1]
x.shape
# Out:
# (517, 28)

# %%
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier

# %%
# create model
model = Sequential()
model.add(Dense(12, input_dim=28, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
model.fit(x, y, validation_split=0.33,epochs=100, batch_size=5)
# Out:
# Epoch 1/100
# 70/70 [==============================] - 2s 5ms/step - loss: 10.1763 - accuracy: 0.7370 - val_loss: 1.3571 - val_accuracy: 0.5848
# Epoch 2/100
# 70/70 [==============================] - 0s 3ms/step - loss: 1.2475 - accuracy: 0.6792 - val_loss: 1.0657 - val_accuracy: 0.7076
# Epoch 3/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.9331 - accuracy: 0.7341 - val_loss: 1.0782 - val_accuracy: 0.7310
# Epoch 4/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.7339 - accuracy: 0.7572 - val_loss: 1.3044 - val_accuracy: 0.7310
# Epoch 5/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.6844 - accuracy: 0.7717 - val_loss: 0.6992 - val_accuracy: 0.7661
# Epoch 6/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.5176 - accuracy: 0.8035 - val_loss: 0.5414 - val_accuracy: 0.7895
# Epoch 7/100
# ...

# %%
# evaluate the model
scores = model.evaluate(x,y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1685 - accuracy: 0.9497
# accuracy: 94.97%
